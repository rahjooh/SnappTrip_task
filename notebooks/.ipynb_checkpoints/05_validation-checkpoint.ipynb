# %% [markdown]
# # Data Validation - Great Expectations
#
# ## Service UIs
# - **Spark Master** (Docker): http://localhost:8082 | **Spark UI** (local): http://localhost:4040
# - **Hadoop UI**: http://localhost:9870 (NameNode) | http://localhost:9864 (DataNode)
# - **HDFS UI**: http://localhost:9870/explorer.html#/lakehouse
# - **Trino UI**: http://localhost:8081
# - **Kafka UI**: http://localhost:9021
# - **Zookeeper**: http://localhost:2181
# - **Airflow UI**: http://localhost:8090 (user: airflow, password: airflow)
# - **Grafana UI**: http://localhost:3000 (user: admin, password: admin)
# - **Postgres**: localhost:5432 (user: airflow, password: airflow)
#
# This notebook demonstrates data quality validation using Great Expectations.
#
# **Note**: This notebook currently has compatibility issues with Great Expectations API.
# For data quality validation, use the DBT tests in notebooks 02-04 instead.

# %%
import sys
import os
sys.path.append('../')

# Set Java 17 for PySpark 3.5.0 compatibility
os.environ['JAVA_HOME'] = '/opt/java/openjdk'

from pyspark.sql import SparkSession
from src.validation import DataValidator, validate_silver_layer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       6 os.environ['JAVA_HOME'] = '/Library/Java/JavaVirtualMachines/temurin-17.jdk/Contents/Home'
#       8 from pyspark.sql import SparkSession
# ----> 9 from src.validation import DataValidator, validate_silver_layer
#
# File /workspace/src/validation/__init__.py:5
#       1 """
#       2 Data validation module using Great Expectations.
#       3 """
# ----> 5 from .great_expectations_validator import DataValidator, validate_silver_layer
#       7 __all__ = ['DataValidator', 'validate_silver_layer']
#
# File /workspace/src/validation/great_expectations_validator.py:11
#       9 from pyspark.sql import DataFrame
#      10 import great_expectations as gx
# ---> 11 from great_expectations import DataContext
#      13 logger = logging.getLogger(__name__)
#      16 class DataValidator:
#
# ...

# %% [markdown]
# ## 1. Initialize Validator

# %%
validator = DataValidator(context_root_dir='../great_expectations')
print("✅ Validator initialized!")

# %% [markdown]
# ## 2. Create Expectation Suite

# %%
suite_name = validator.create_silver_expectations()
print(f"✅ Created expectation suite: {suite_name}")

# %% [markdown]
# ## 3. Load Sample Data

# %%
spark = SparkSession.builder \
    .appName("Validation-Test") \
    .master("spark://localhost:7077") \
    .config("spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.4.3,org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.local.type", "hadoop") \
    .config("spark.sql.catalog.local.warehouse", "/tmp/lakehouse") \
    .getOrCreate()

# Create sample data
from datetime import datetime

data = [
    ("B001", "U001", "H001", "confirmed", 100.0, datetime(2024,1,1), datetime(2024,1,1)),
    ("B002", "U002", "H002", "cancelled", 200.0, datetime(2024,1,2), datetime(2024,1,2)),
    ("B003", "U003", "H003", "created", 150.0, datetime(2024,1,3), datetime(2024,1,3)),
]

df = spark.createDataFrame(data, 
    ["booking_id", "user_id", "hotel_id", "status", "price", "created_at", "updated_at"])

df.show()

# %% [markdown]
# ## 4. Validate Data

# %%
# Run validation
results = validator.validate_dataframe(df, suite_name)

# Display results
print(f"Validation success: {results['success']}")
print(f"Total expectations: {results['statistics']['evaluated_expectations']}")
print(f"Successful: {results['statistics']['successful_expectations']}")
print(f"Failed: {results['statistics']['unsuccessful_expectations']}")
